# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\97798\Desktop\Week 10\bank_data.csv", sep = ',')

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# Age Distribution of Users

# %%
sns.histplot(
data = data,
x = 'age',
kde = True)

# Most Users of age range 20 to 40
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# Categories of jobs

# %%
plt.figure(figsize=(15,5))
plt.tight_layout()
sns.countplot(
data = data,
x = 'job',
)
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %% [markdown]
# Relationship between job and y

# %%
plt.figure(figsize=(15, 5))
ax = sns.countplot(data=data, x='job', hue='y', palette='Set1')
plt.xlabel('Job')
plt.ylabel('Percentage')
plt.title('Relationship between Job and Y (Percentage)')
plt.legend(title='Y', loc='upper right')
plt.xticks(rotation=45)

# Calculate and display percentages
total = len(data)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height), ha='center')

plt.show()

# %% [markdown]
# Distribution of contact column

# %%
plt.figure(figsize=(10
                    , 10))

data.month.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(15, 5))

data.day_of_week.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
data.default.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
data.housing.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
data.loan.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
data.contact.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(
data = data,
x = 'duration',
kde = True)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'campaign',
kde = True)
# Out:
# <Axes: xlabel='campaign', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'pdays',
kde = True)
# Out:
# <Axes: xlabel='pdays', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'previous',
kde = True)
# Out:
# <Axes: xlabel='previous', ylabel='Count'>

# %%
data.poutcome.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(
data = data,
x = 'emp.var.rate',
kde = True)
# Out:
# <Axes: xlabel='emp.var.rate', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'cons.price.idx',
kde = True)
# Out:
# <Axes: xlabel='cons.price.idx', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'euribor3m',
kde = True)
# Out:
# <Axes: xlabel='euribor3m', ylabel='Count'>

# %%
sns.histplot(
data = data,
x = 'nr.employed',
kde = True)
# Out:
# <Axes: xlabel='nr.employed', ylabel='Count'>

# %%
data.y.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10,10))
data.education.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10,10))
data.job.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10,10))
data.marital.value_counts().plot(kind = 'pie',autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Relationship between education and job

# %%
plt.figure(figsize=(10,5
                   ))
sns.countplot(data=data, x="education", hue="job", palette="Set2")

plt.show()

# %%
data.education = data.education.str.replace('unknown','university.degree')

# %%
num_features = data.select_dtypes(exclude='object')

# %%
num_features
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
cat_features = data.select_dtypes(include='object')

# %%
cat_features
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome    y
# 0      telephone   may         mon  nonexistent   no
# ...

# %%
from scipy.stats import chi2_contingency

# Example data
# Create a contingency table
contingency_table = pd.crosstab(data['job'], data['education'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-Square Statistic: 37338.1351562161
# P-value: 0.0

# %%
sns.regplot(
data = data, 
x = 'age',
y ='duration')
# Out:
# <Axes: xlabel='age', ylabel='duration'>

# %%
sns.regplot(
data = data, 
x = 'age',
y ='campaign')
# Out:
# <Axes: xlabel='age', ylabel='campaign'>

# %%
sns.regplot(
data = data, 
x = 'age',
y ='pdays')
# Out:
# <Axes: xlabel='age', ylabel='pdays'>

# %%
plt.tight_layout()
plt.figure(figsize=(20,10))
sns.countplot(
data = data,
x = 'job', 
hue = 'education')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
plt.tight_layout()
plt.figure(figsize=(20,10))
sns.countplot(
data = data,
x = 'job', 
hue = 'default')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
plt.tight_layout()
plt.figure(figsize=(20,10))
sns.countplot(
data = data,
x = 'job', 
hue = 'y')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
data.loan = data.loan.str.replace('unknown','no')

# %%
def remove_outliers_iqr(df):
    outliers = {}
    for col in df.columns:
        if np.issubdtype(df[col].dtype, np.number):  # Check if the column contains numerical data
            # Calculate the IQR (Interquartile Range) for the column
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            
            # Define lower and upper bounds for outliers
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            
            # Find the indices of outliers
            outlier_indices = (df[col] < lower_bound) | (df[col] > upper_bound)
            
            # Create a DataFrame containing the outliers
            col_outliers = df[outlier_indices]
            
            # Add the outliers to the dictionary
            outliers[col] = col_outliers
    
    # Remove the rows containing outliers from the original DataFrame
    for col, col_outliers in outliers.items():
        df = df[~df.index.isin(col_outliers.index)]
    
    # Print information about removed outliers and the new shape
    if outliers:
        print('These outliers have been removed from your dataset:')
        for col, col_outliers in outliers.items():
            print(f'\nOutliers in column "{col}":')
            print(col_outliers)
    else:
        print('No outliers were found in the dataset.')
    
    print('\nNew shape is:', df.shape)
    return df

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40        admin  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41180   36        admin  married    university.degree       no      no   no
# 41181   37        admin  married    university.degree       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
#
# ...

# %%
data.to_csv('bank_data.csv')

# %%
# Create a correlation matrix for your dataset
correlation_matrix = num_features.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Set up the heatmap figure
plt.figure(figsize=(10, 8))

# Create the heatmap using seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", mask = mask)

# Set the title
plt.title('Correlation Heatmap')

# Show the plot
plt.show()

# %%
data
# Out:
#        Unnamed: 0  age          job  marital            education  default  \
# 0               0   56    housemaid  married             basic.4y       no
# 1               1   57     services  married          high.school  unknown
# 2               2   37     services  married          high.school       no
# 3               3   40        admin  married             basic.6y       no
# 4               4   56     services  married          high.school       no
# ...           ...  ...          ...      ...                  ...      ...
# 30355       41180   36        admin  married    university.degree       no
# 30356       41181   37        admin  married    university.degree       no
# 30357       41184   46  blue-collar  married  professional.course       no
# 30358       41185   56      retired  married    university.degree       no
# 30359       41186   44   technician  married  professional.course       no
#
# ...

# %%
data.drop('Unnamed: 0', axis =1 ,inplace = True)

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40        admin  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 30355   36        admin  married    university.degree       no      no   no
# 30356   37        admin  married    university.degree       no     yes   no
# 30357   46  blue-collar  married  professional.course       no      no   no
# 30358   56      retired  married    university.degree       no     yes   no
# 30359   44   technician  married  professional.course       no      no   no
#
# ...

# %%
yes_data = data[data.y == 'yes']

# %%
no_data = data[data.y == 'no']

# %%
no_data
# Out:
#        age          job   marital            education  default housing loan  \
# 0       56    housemaid   married             basic.4y       no      no   no
# 1       57     services   married          high.school  unknown      no   no
# 2       37     services   married          high.school       no     yes   no
# 3       40        admin   married             basic.6y       no      no   no
# 4       56     services   married          high.school       no      no  yes
# ...    ...          ...       ...                  ...      ...     ...  ...
# 30353   57      retired   married  professional.course       no     yes   no
# 30354   64      retired  divorced  professional.course       no     yes   no
# 30355   36        admin   married    university.degree       no      no   no
# 30357   46  blue-collar   married  professional.course       no      no   no
# 30358   56      retired   married    university.degree       no     yes   no
#
# ...

# %%
yes_data
# Out:
#        age          job   marital            education  default housing loan  \
# 122     41   technician   married  professional.course  unknown     yes   no
# 131     45  blue-collar   married             basic.9y  unknown     yes   no
# 822     37  blue-collar    single             basic.9y  unknown     yes   no
# 1118    46  blue-collar    single             basic.9y       no     yes   no
# 1240    54        admin   married    university.degree       no      no   no
# ...    ...          ...       ...                  ...      ...     ...  ...
# 30346   38    housemaid  divorced    university.degree       no      no   no
# 30350   33      student   married  professional.course       no     yes   no
# 30351   31        admin    single    university.degree       no     yes   no
# 30356   37        admin   married    university.degree       no     yes   no
# 30359   44   technician   married  professional.course       no      no   no
#
# ...

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40        admin  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 30355   36        admin  married    university.degree       no      no   no
# 30356   37        admin  married    university.degree       no     yes   no
# 30357   46  blue-collar  married  professional.course       no      no   no
# 30358   56      retired  married    university.degree       no     yes   no
# 30359   44   technician  married  professional.course       no      no   no
#
# ...

# %%
plt.figure(figsize=(15,4))
sns.countplot(
data = data,
x = 'loan', 
hue = 'y')
# Out:
# <Axes: xlabel='loan', ylabel='count'>
