# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn import pipeline
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r"C:\Users\97798\Desktop\archive\Life Expectancy Data.csv")

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
X = data.drop('Life expectancy ', axis =1)

# %%
X
# Out:
#           Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0     Afghanistan  2015  Developing            263.0             62     0.01
# 1     Afghanistan  2014  Developing            271.0             64     0.01
# 2     Afghanistan  2013  Developing            268.0             66     0.01
# 3     Afghanistan  2012  Developing            272.0             69     0.01
# 4     Afghanistan  2011  Developing            275.0             71     0.01
# ...           ...   ...         ...              ...            ...      ...
# 2933     Zimbabwe  2004  Developing            723.0             27     4.36
# 2934     Zimbabwe  2003  Developing            715.0             26     4.06
# 2935     Zimbabwe  2002  Developing             73.0             25     4.43
# 2936     Zimbabwe  2001  Developing            686.0             25     1.72
# 2937     Zimbabwe  2000  Developing            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0                  71.279624         65.0      1154   19.1  ...    6.0
# 1                  73.523582         62.0       492   18.6  ...   58.0
# 2                  73.219243         64.0       430   18.1  ...   62.0
# 3                  78.184215         67.0      2787   17.6  ...   67.0
# 4                   7.097109         68.0      3013   17.2  ...   68.0
# ...                      ...          ...       ...    ...  ...    ...
# 2933                0.000000         68.0        31   27.1  ...   67.0
# 2934                0.000000          7.0       998   26.7  ...    7.0
# 2935                0.000000         73.0       304   26.3  ...   73.0
# 2936                0.000000         76.0       529   25.9  ...   76.0
# 2937                0.000000         79.0      1483   25.5  ...   78.0
#
#       Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0                  8.16         65.0        0.1  584.259210  33736494.0
# 1                  8.18         62.0        0.1  612.696514    327582.0
# 2                  8.13         64.0        0.1  631.744976  31731688.0
# 3                  8.52         67.0        0.1  669.959000   3696958.0
# 4                  7.87         68.0        0.1   63.537231   2978599.0
# ...                 ...          ...        ...         ...         ...
# 2933               7.13         65.0       33.6  454.366654  12777511.0
# 2934               6.52         68.0       36.7  453.351155  12633897.0
# 2935               6.53         71.0       39.8   57.348340    125525.0
# 2936               6.16         75.0       42.1  548.587312  12366165.0
# 2937               7.10         78.0       43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 21 columns]

# %%
y = data['Life expectancy ']

# %%
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
X_train , X_test, y_train, y_test = train_test_split(X, y , test_size=0.2)

# %%
y_train
# Out:
# array([[73.3],
#        [73.1],
#        [65.2],
#        ...,
#        [82. ],
#        [59.8],
#        [77. ]])

# %%
from sklearn.impute import KNNImputer
import numpy as np

# Assuming X_test is your test data with features including 'BMI'
imputer = KNNImputer(n_neighbors=5)  # You can adjust the n_neighbors parameter as needed

# Reshape the input to a 2D array-like structure using numpy's reshape
X_test_imputed = imputer.fit_transform(X_train[['Adult Mortality']])

# Replace the 'BMI' column in X_test with the imputed values
X_train['Adult Mortality'] = X_test_imputed

# %%
X_train.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
X_train.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# Detecting and removing outliers

# %%
def remove_outliers(df):
    outliers = {}
    for col in df.columns:
        if str(df[col].dtype) != 'object':
            df = df[np.abs(df[col]-df[col].mean()) < (3*df[col].std())]
            olrs = df[~(np.abs(df[col]-df[col].mean()) < (3*df[col].std()))]
            outliers = pd.DataFrame(olrs)
    
    return print('These outliers have been removed from your dataset: \n\n', outliers,
                'New shape is:', df.shape)

# %%
remove_outliers(X_train)
# Out:
# These outliers have been removed from your dataset:
#
#       Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 1885   Niger  2007  Developing            276.0             53      0.1
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 1885               35.809297    81.019854       282   16.1  ...   57.0
#
#       Total expenditure  Diphtheria    HIV/AIDS        GDP  Population  \
# 1885               6.94         57.0        1.4  292.55962  14668338.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 1885                   11.4                 11.3
#
#       Income composition of resources  Schooling
# 1885                            0.293        3.8
#
# [1 rows x 21 columns] New shape is: (1598, 21)

# %%
X_train
# Out:
#                        Country  Year      Status  Adult Mortality  \
# 223                   Barbados  2000  Developing            127.0
# 1045                   Grenada  2012  Developing            146.0
# 1194                     India  2007  Developing             26.0
# 1538                Luxembourg  2015   Developed             63.0
# 2799  United States of America  2010   Developed             15.0
# ...                        ...   ...         ...              ...
# 497                     Canada  2014  Developing             65.0
# 287                      Benin  2000  Developing            279.0
# 2428                     Spain  2012   Developed             61.0
# 761                   Djibouti  2007  Developing            296.0
# 2814                   Uruguay  2011  Developing            111.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 223               0  7.43000             1140.615754    81.019854         0
# 1045              0  8.07000              865.999978    97.000000         0
# 1194           1400  1.59000                5.234770     6.000000     41144
# 1538              0  4.55382                0.000000    94.000000         0
# 2799             25  8.55000                0.000000    92.000000        63
# ...             ...      ...                     ...          ...       ...
# 497               2  8.10000              102.190217    55.000000       418
# 287              25  1.34000               37.381820    81.019854      4244
# 2428              1  9.35000             4255.781693    96.000000      1204
# 761               1  0.45000               20.868787    25.000000        24
# 2814              0  5.97000              417.911744    95.000000         0
#
#        BMI   ...  Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 223    43.0  ...   86.0           5.160000         93.0        0.9
# 1045   45.6  ...   98.0           6.360000         97.0        0.1
# 1194   14.4  ...   67.0           4.230000         64.0        0.3
# 1538   61.3  ...   99.0           5.925337         99.0        0.1
# 2799   66.9  ...   93.0          17.200000         95.0        0.1
# ...     ...  ...    ...                ...          ...        ...
# 497    66.4  ...   91.0           1.450000         91.0        0.1
# 287    18.4  ...   78.0           4.340000         78.0        2.0
# 2428   64.8  ...   97.0           9.390000         97.0        0.1
# 761     3.9  ...   88.0           7.720000         88.0        3.5
# 2814   61.8  ...   95.0           8.550000         95.0        0.1
#
#                GDP    Population   thinness  1-19 years   thinness 5-9 years  \
# 223   11568.111100  1.288628e+07                    4.3                  4.2
# 1045   7583.187200  1.288628e+07                    3.8                  3.8
# 1194    118.166373  1.179681e+09                   27.1                 28.0
# 1538   1199.822300  5.696400e+04                    1.0                  0.9
# 2799   7229.561623  1.288628e+07                    0.7                  0.6
# ...            ...           ...                    ...                  ...
# 497     544.433760  3.554456e+07                    0.5                  0.5
# 287     374.192394  6.865951e+06                    9.7                  9.6
# 2428  28562.293240  4.677355e+06                    0.6                  0.5
# 761     147.586896  8.942000e+03                    5.8                  5.7
# 2814  14166.499800  3.385624e+06                    1.5                  1.5
#
#       Income composition of resources  Schooling
# 223                          0.741000    14.0000
# 1045                         0.744000    15.8000
# 1194                         0.546000     9.9000
# 1538                         0.896000    13.9000
# 2799                         0.627777    11.9491
# ...                               ...        ...
# 497                          0.912000    15.9000
# 287                          0.389000     6.4000
# 2428                         0.871000    17.2000
# 761                          0.416000     4.5000
# 2814                         0.780000    15.5000
#
# [2350 rows x 21 columns]

# %%
num_features = X_train.select_dtypes(exclude='object')
num_features
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 223   2000            127.0              0  7.43000             1140.615754
# 1045  2012            146.0              0  8.07000              865.999978
# 1194  2007             26.0           1400  1.59000                5.234770
# 1538  2015             63.0              0  4.55382                0.000000
# 2799  2010             15.0             25  8.55000                0.000000
# ...    ...              ...            ...      ...                     ...
# 497   2014             65.0              2  8.10000              102.190217
# 287   2000            279.0             25  1.34000               37.381820
# 2428  2012             61.0              1  9.35000             4255.781693
# 761   2007            296.0              1  0.45000               20.868787
# 2814  2011            111.0              0  5.97000              417.911744
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  \
# 223     81.019854         0   43.0                   0   86.0
# 1045    97.000000         0   45.6                   0   98.0
# 1194     6.000000     41144   14.4                1900   67.0
# 1538    94.000000         0   61.3                   0   99.0
# 2799    92.000000        63   66.9                  30   93.0
# ...           ...       ...    ...                 ...    ...
# 497     55.000000       418   66.4                   2   91.0
# 287     81.019854      4244   18.4                  40   78.0
# 2428    96.000000      1204   64.8                   2   97.0
# 761     25.000000        24    3.9                   2   88.0
# 2814    95.000000         0   61.8                   1   95.0
#
#       Total expenditure  Diphtheria    HIV/AIDS           GDP    Population  \
# 223            5.160000         93.0        0.9  11568.111100  1.288628e+07
# 1045           6.360000         97.0        0.1   7583.187200  1.288628e+07
# 1194           4.230000         64.0        0.3    118.166373  1.179681e+09
# 1538           5.925337         99.0        0.1   1199.822300  5.696400e+04
# 2799          17.200000         95.0        0.1   7229.561623  1.288628e+07
# ...                 ...          ...        ...           ...           ...
# 497            1.450000         91.0        0.1    544.433760  3.554456e+07
# 287            4.340000         78.0        2.0    374.192394  6.865951e+06
# 2428           9.390000         97.0        0.1  28562.293240  4.677355e+06
# 761            7.720000         88.0        3.5    147.586896  8.942000e+03
# 2814           8.550000         95.0        0.1  14166.499800  3.385624e+06
#
#        thinness  1-19 years   thinness 5-9 years  \
# 223                     4.3                  4.2
# 1045                    3.8                  3.8
# 1194                   27.1                 28.0
# 1538                    1.0                  0.9
# 2799                    0.7                  0.6
# ...                     ...                  ...
# 497                     0.5                  0.5
# 287                     9.7                  9.6
# 2428                    0.6                  0.5
# 761                     5.8                  5.7
# 2814                    1.5                  1.5
#
#       Income composition of resources  Schooling
# 223                          0.741000    14.0000
# 1045                         0.744000    15.8000
# 1194                         0.546000     9.9000
# 1538                         0.896000    13.9000
# 2799                         0.627777    11.9491
# ...                               ...        ...
# 497                          0.912000    15.9000
# 287                          0.389000     6.4000
# 2428                         0.871000    17.2000
# 761                          0.416000     4.5000
# 2814                         0.780000    15.5000
#
# [2350 rows x 19 columns]

# %%
cat_features = X_train.select_dtypes(include='object')
cat_features
# Out:
#                        Country      Status
# 223                   Barbados  Developing
# 1045                   Grenada  Developing
# 1194                     India  Developing
# 1538                Luxembourg   Developed
# 2799  United States of America   Developed
# ...                        ...         ...
# 497                     Canada  Developing
# 287                      Benin  Developing
# 2428                     Spain   Developed
# 761                   Djibouti  Developing
# 2814                   Uruguay  Developing
#
# [2350 rows x 2 columns]

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(num_features, 0.85)
corr_features
# Out:
# {' thinness 5-9 years', 'GDP', 'under-five deaths '}

# %%
X_test.drop(corr_features, axis=1, inplace = True)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LassoLarsCV, RANSACRegressor, ElasticNet, Lasso, SGDClassifier,ARDRegression, HuberRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.ensemble import HistGradientBoostingRegressor,BaggingRegressor, GradientBoostingRegressor

from sklearn.metrics import *
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder( sparse = False,drop='first', handle_unknown='ignore'),cat_features.columns),
        ('num_tnf', MinMaxScaler(feature_range=(0,1
                                               )), num_features.columns)
    ],
    remainder='passthrough'
)

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, PoissonRegressor
from sklearn.ensemble import (
    RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor,
    BaggingRegressor, ExtraTreesRegressor
)
from sklearn.svm import SVR
from sklearn.metrics import r2_score
import warnings

# Create a sample dataset


# Create a function to evaluate different models
def evaluate_model(model, X_train, y_train, X_test, y_test):
        pipe = Pipeline([
            ('Transform', step1),
            ('model', model),
        ])
        
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        return r2

# Split the dataset into train and test sets


# Initialize different models
models = {
    'Linear Regression': LinearRegression(),
    'Poisson Regressor': PoissonRegressor(),
    'Random Forest Regressor': RandomForestRegressor(),
    'Gradient Boosting Regressor': GradientBoostingRegressor(),
    'AdaBoost Regressor': AdaBoostRegressor(),
    'Bagging Regressor': BaggingRegressor(),
    'Extra Trees Regressor': ExtraTreesRegressor(),
    'Support Vector Regressor': SVR(),
    
}

# Evaluate and print R2 scores for different models
for model_name, model in models.items():
    r2 = evaluate_model(model, X_train, y_train, X_test, y_test)
    print(f'R2 Score for {model_name}: {r2:.4f}')
# Out:
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# R2 Score for Linear Regression: 0.9539
# R2 Score for Poisson Regressor: 0.8290
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# R2 Score for Random Forest Regressor: 0.9650
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# R2 Score for Gradient Boosting Regressor: 0.9394
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:508: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# R2 Score for AdaBoost Regressor: 0.8891
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# R2 Score for Bagging Regressor: 0.9621
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# R2 Score for Extra Trees Regressor: 0.9734
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# R2 Score for Support Vector Regressor: 0.8838

# %%
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor, ExtraTreesRegressor

# Initialize the Extra Trees Regressor
et_regressor = ExtraTreesRegressor()

# Define the hyperparameter search space for Extra Trees Regressor
param_grid_et = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False],
    'random_state': [42]  # You can adjust this value
}

# Perform hyperparameter tuning using RandomizedSearchCV for Extra Trees Regressor
random_search_et = RandomizedSearchCV(et_regressor, param_distributions=param_grid_et, n_iter=10, cv=5, n_jobs=-1)
r2_et = evaluate_model(random_search_et, X_train, y_train, X_test, y_test)
print(f'R2 Score after hyperparameter tuning (Extra Trees): {r2_et:.4f}')
print(f'Best parameters found (Extra Trees): {random_search_et.best_params_}')
# Out:
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# R2 Score after hyperparameter tuning (Extra Trees): 0.9663
# Best parameters found (Extra Trees): {'random_state': 42, 'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 20, 'bootstrap': False}
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step2 = ExtraTreesRegressor(
    random_state=42,
    max_depth=20,
    bootstrap=False,
    max_features='auto',
    min_samples_leaf=4,
    min_samples_split=2,
    n_estimators=50
)

# Create the pipeline
pipe = Pipeline([
    ('Transform', step1),
    ('ETRegressor', step2)
])

# Fit the pipeline
pipe.fit(X_train, y_train)
# Out:
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# Pipeline(steps=[('Transform',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Country', 'Status'], dtype='object')),
#                                                  ('num_tnf', MinMaxScaler(),
#                                                   Index(['Year', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'Polio',
#        'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'Population',
#        ' thinness  1-19 years', 'Income composition of resources',
#        'Schooling'],
#       dtype='object'))])),
#                 ('ETRegressor',
#                  ExtraTreesRegressor(max_depth=20, max_features='auto',
#                                      min_samples_leaf=4, n_estimators=50,
#                                      random_state=42))])

# %%
y_pred = pipe.predict(X_test)
# Out:
# C:\Users\97798\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pandas as pd

y_test = pd.Series(y_test.squeeze(), name='Actual')
predicted_series = pd.Series(y_pred, name='Predicted')

diff = pd.DataFrame({
    'Actual': y_test,
    'Predicted': predicted_series
})

# Print the resulting DataFrame
print(diff)
# Out:
#      Actual  Predicted
# 0      72.7  70.634940
# 1      58.0  52.258971
# 2      67.2  67.201878
# 3      58.8  58.612881
# 4      71.5  72.111464
# ..      ...        ...
# 583    78.0  74.468510
# 584    69.9  71.599462
# 585    66.6  67.335462
# 586    66.2  65.458757
# 587    72.7  74.093297
#
# [588 rows x 2 columns]

# %%
diff
# Out:
#      Actual  Predicted
# 0      72.7  70.634940
# 1      58.0  52.258971
# 2      67.2  67.201878
# 3      58.8  58.612881
# 4      71.5  72.111464
# ..      ...        ...
# 583    78.0  74.468510
# 584    69.9  71.599462
# 585    66.6  67.335462
# 586    66.2  65.458757
# 587    72.7  74.093297
#
# [588 rows x 2 columns]

# %%
sns.lineplot(diff)
# Out:
# <Axes: >

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9662589882071195

# %%
import pickle

# Assuming 'model' is your trained machine learning model
model_filename = 'who_model.pkl'

# Save the model to a file using pickle
with open(model_filename, 'wb') as file:
    pickle.dump(model, file)

print(f"Model saved as '{model_filename}'")
# Out:
# Model saved as 'who_model.pkl'
